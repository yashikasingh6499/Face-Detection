# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('../input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# ../input/samples/samples.pkl
# ../input/picimage/lena.png

# %%
import cv2
import dlib
import numpy as np
import matplotlib.pyplot as plt
import _pickle as pkl
from keras.models import Sequential, load_model
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %matplotlib inline

# %%
x, y = pkl.load(open('../input/samples/samples.pkl', 'rb'))

print(x.shape, y.shape)
# Out:
# (6288, 2278) (6288, 3)

# %%
roll, pitch, yaw = y[:, 0], y[:, 1], y[:, 2]

print(roll.min(), roll.max(), roll.mean(), roll.std())
print(pitch.min(), pitch.max(), pitch.mean(), pitch.std())
print(yaw.min(), yaw.max(), yaw.mean(), yaw.std())
# Out:
# -46.06486893 43.00866699 -0.52579503197042 5.176231116713095
# -29.88856888 34.09674835 2.584682740273537 7.962828151857226
# -75.55059814 86.84925079 -0.11620588007315523 13.090839183150852

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_test, y_test, test_size=0.5, random_state=42)

print(x_train.shape, y_train.shape)
print(x_val.shape, y_val.shape)
print(x_test.shape, y_test.shape)
# Out:
# (4401, 2278) (4401, 3)
# (943, 2278) (943, 3)
# (944, 2278) (944, 3)

# %%
std = StandardScaler()
std.fit(x_train)
x_train = std.transform(x_train)
x_val = std.transform(x_val)
x_test = std.transform(x_test)

# %%
BATCH_SIZE = 64
EPOCHS = 100

# %%
model = Sequential()
model.add(Dense(units=20, activation='relu', kernel_regularizer='l2', input_dim=x.shape[1]))
model.add(Dense(units=10, activation='relu', kernel_regularizer='l2'))
model.add(Dense(units=3, activation='linear'))

print(model.summary())

callback_list = [EarlyStopping(monitor='val_loss', patience=25)]

model.compile(optimizer='adam', loss='mean_squared_error')
hist = model.fit(x=x_train, y=y_train, validation_data=(x_val, y_val), batch_size=BATCH_SIZE, epochs=EPOCHS, callbacks=callback_list)
model.save('model.h5')

print()
print('Train loss:', model.evaluate(x_train, y_train, verbose=0))
print('  Val loss:', model.evaluate(x_val, y_val, verbose=0))
print(' Test loss:', model.evaluate(x_test, y_test, verbose=0))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 20)                45580
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                210
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 33
# =================================================================
# Total params: 45,823
# Trainable params: 45,823
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 69/69 [==============================] - 0s 4ms/step - loss: 68.6545 - val_loss: 48.9765
# Epoch 2/100
# 69/69 [==============================] - 0s 3ms/step - loss: 43.7725 - val_loss: 46.5556
# Epoch 3/100
# 69/69 [==============================] - 0s 3ms/step - loss: 39.4014 - val_loss: 40.1273
# Epoch 4/100
# 69/69 [==============================] - 0s 3ms/step - loss: 37.1828 - val_loss: 36.9454
# Epoch 5/100
# 69/69 [==============================] - 0s 3ms/step - loss: 35.6801 - val_loss: 36.5826
# Epoch 6/100
# 69/69 [==============================] - 0s 3ms/step - loss: 34.6086 - val_loss: 35.8826
# Epoch 7/100
# 69/69 [==============================] - 0s 3ms/step - loss: 34.2673 - val_loss: 35.7730
# Epoch 8/100
# 69/69 [==============================] - 0s 3ms/step - loss: 33.6163 - val_loss: 37.2557
# Epoch 9/100
# 69/69 [==============================] - 0s 3ms/step - loss: 33.8924 - val_loss: 36.5022
# Epoch 10/100
# 69/69 [==============================] - 0s 3ms/step - loss: 33.6734 - val_loss: 38.1398
# Epoch 11/100
# 69/69 [==============================] - 0s 3ms/step - loss: 33.9806 - val_loss: 35.4741
# Epoch 12/100
# 69/69 [==============================] - 0s 3ms/step - loss: 33.1150 - val_loss: 35.7240
# Epoch 13/100
# 69/69 [==============================] - 0s 3ms/step - loss: 33.6507 - val_loss: 35.5418
# Epoch 14/100
# 69/69 [==============================] - 0s 3ms/step - loss: 32.8197 - val_loss: 33.8729
# Epoch 15/100
# 69/69 [==============================] - 0s 3ms/step - loss: 32.7101 - val_loss: 34.5874
# Epoch 16/100
# 69/69 [==============================] - 0s 3ms/step - loss: 32.3947 - val_loss: 33.5799
# Epoch 17/100
# 69/69 [==============================] - 0s 3ms/step - loss: 32.5349 - val_loss: 37.0123
# Epoch 18/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.8319 - val_loss: 34.8222
# Epoch 19/100
# 69/69 [==============================] - 0s 6ms/step - loss: 32.3413 - val_loss: 36.0521
# Epoch 20/100
# 69/69 [==============================] - 0s 4ms/step - loss: 32.3671 - val_loss: 33.3905
# Epoch 21/100
# 69/69 [==============================] - 0s 4ms/step - loss: 33.0878 - val_loss: 33.5527
# Epoch 22/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.8046 - val_loss: 33.6592
# Epoch 23/100
# 69/69 [==============================] - 0s 3ms/step - loss: 32.3216 - val_loss: 34.3141
# Epoch 24/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.8044 - val_loss: 33.9947
# Epoch 25/100
# 69/69 [==============================] - 0s 3ms/step - loss: 32.1293 - val_loss: 34.8922
# Epoch 26/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.4333 - val_loss: 33.8358
# Epoch 27/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.9565 - val_loss: 38.3826
# Epoch 28/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.9139 - val_loss: 34.8994
# Epoch 29/100
# 69/69 [==============================] - 0s 3ms/step - loss: 32.2960 - val_loss: 33.3218
# Epoch 30/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.9502 - val_loss: 33.8475
# Epoch 31/100
# 69/69 [==============================] - 0s 3ms/step - loss: 32.1913 - val_loss: 34.2531
# Epoch 32/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.8112 - val_loss: 33.9325
# Epoch 33/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.4346 - val_loss: 34.0810
# Epoch 34/100
# 69/69 [==============================] - 0s 3ms/step - loss: 32.0145 - val_loss: 34.1095
# Epoch 35/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.0713 - val_loss: 34.1999
# Epoch 36/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.3582 - val_loss: 37.3944
# Epoch 37/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.8031 - val_loss: 33.5974
# Epoch 38/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.8142 - val_loss: 33.0441
# Epoch 39/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.1691 - val_loss: 33.5842
# Epoch 40/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.4395 - val_loss: 33.0626
# Epoch 41/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.9691 - val_loss: 33.0236
# Epoch 42/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.9426 - val_loss: 33.3282
# Epoch 43/100
# 69/69 [==============================] - 0s 4ms/step - loss: 30.9777 - val_loss: 34.9312
# Epoch 44/100
# 69/69 [==============================] - 0s 5ms/step - loss: 31.6180 - val_loss: 33.2688
# Epoch 45/100
# 69/69 [==============================] - 0s 6ms/step - loss: 30.8597 - val_loss: 32.7628
# Epoch 46/100
# 69/69 [==============================] - 0s 4ms/step - loss: 30.3166 - val_loss: 32.2899
# Epoch 47/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.6911 - val_loss: 37.8720
# Epoch 48/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.6239 - val_loss: 34.0117
# Epoch 49/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.2542 - val_loss: 35.4976
# Epoch 50/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.0377 - val_loss: 33.0294
# Epoch 51/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.7586 - val_loss: 36.6364
# Epoch 52/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.3027 - val_loss: 34.8069
# Epoch 53/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.4543 - val_loss: 32.7247
# Epoch 54/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.0843 - val_loss: 33.7767
# Epoch 55/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.8585 - val_loss: 32.0866
# Epoch 56/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.2884 - val_loss: 32.8039
# Epoch 57/100
# 69/69 [==============================] - 0s 4ms/step - loss: 30.4908 - val_loss: 32.1981
# Epoch 58/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.6265 - val_loss: 32.3012
# Epoch 59/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.1095 - val_loss: 32.2212
# Epoch 60/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.9013 - val_loss: 32.8572
# Epoch 61/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.6062 - val_loss: 32.5416
# Epoch 62/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.9125 - val_loss: 33.4294
# Epoch 63/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.9305 - val_loss: 34.7773
# Epoch 64/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.7512 - val_loss: 35.6101
# Epoch 65/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.5773 - val_loss: 35.6461
# Epoch 66/100
# 69/69 [==============================] - 0s 3ms/step - loss: 31.6041 - val_loss: 31.8706
# Epoch 67/100
# 69/69 [==============================] - 0s 3ms/step - loss: 29.8838 - val_loss: 34.5043
# Epoch 68/100
# 69/69 [==============================] - 0s 4ms/step - loss: 29.7576 - val_loss: 31.7278
# Epoch 69/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.0849 - val_loss: 32.1868
# Epoch 70/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.0262 - val_loss: 33.0592
# Epoch 71/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.2638 - val_loss: 33.9312
# Epoch 72/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.4563 - val_loss: 32.6685
# Epoch 73/100
# 69/69 [==============================] - 0s 3ms/step - loss: 29.8312 - val_loss: 32.1165
# Epoch 74/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.1047 - val_loss: 32.1972
# Epoch 75/100
# 69/69 [==============================] - 0s 3ms/step - loss: 29.5969 - val_loss: 33.0670
# Epoch 76/100
# 69/69 [==============================] - 0s 3ms/step - loss: 29.6839 - val_loss: 31.8934
# Epoch 77/100
# 69/69 [==============================] - 0s 3ms/step - loss: 29.8011 - val_loss: 32.0265
# Epoch 78/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.4592 - val_loss: 31.6485
# Epoch 79/100
# 69/69 [==============================] - 0s 3ms/step - loss: 29.4436 - val_loss: 32.2663
# Epoch 80/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.1272 - val_loss: 31.8440
# Epoch 81/100
# 69/69 [==============================] - 0s 3ms/step - loss: 29.4247 - val_loss: 31.4872
# Epoch 82/100
# 69/69 [==============================] - 0s 3ms/step - loss: 29.1687 - val_loss: 32.4548
# Epoch 83/100
# 69/69 [==============================] - 0s 3ms/step - loss: 29.5991 - val_loss: 31.2937
# Epoch 84/100
# 69/69 [==============================] - 0s 3ms/step - loss: 29.7603 - val_loss: 32.2454
# Epoch 85/100
# 69/69 [==============================] - 0s 3ms/step - loss: 29.3859 - val_loss: 31.3484
# Epoch 86/100
# 69/69 [==============================] - 0s 3ms/step - loss: 29.2421 - val_loss: 33.7863
# Epoch 87/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.8144 - val_loss: 35.6806
# Epoch 88/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.0886 - val_loss: 32.8477
# Epoch 89/100
# 69/69 [==============================] - 0s 3ms/step - loss: 29.5835 - val_loss: 31.4612
# Epoch 90/100
# 69/69 [==============================] - 0s 3ms/step - loss: 29.2725 - val_loss: 32.2054
# Epoch 91/100
# 69/69 [==============================] - 0s 3ms/step - loss: 29.6912 - val_loss: 31.4456
# Epoch 92/100
# 69/69 [==============================] - 0s 3ms/step - loss: 29.0851 - val_loss: 31.5256
# Epoch 93/100
# 69/69 [==============================] - 0s 4ms/step - loss: 29.4379 - val_loss: 33.2847
# Epoch 94/100
# 69/69 [==============================] - 0s 4ms/step - loss: 29.5107 - val_loss: 31.6829
# Epoch 95/100
# 69/69 [==============================] - 0s 4ms/step - loss: 29.3034 - val_loss: 32.2437
# Epoch 96/100
# 69/69 [==============================] - 0s 3ms/step - loss: 30.0104 - val_loss: 31.7014
# Epoch 97/100
# 69/69 [==============================] - 0s 3ms/step - loss: 29.4518 - val_loss: 31.8528
# Epoch 98/100
# 69/69 [==============================] - 0s 3ms/step - loss: 29.7858 - val_loss: 30.8059
# Epoch 99/100
# 69/69 [==============================] - 0s 3ms/step - loss: 29.1652 - val_loss: 31.5114
# Epoch 100/100
# 69/69 [==============================] - 0s 3ms/step - loss: 29.1994 - val_loss: 30.5048
#
# Train loss: 27.82320213317871
#   Val loss: 30.504758834838867
#  Test loss: 38.51972579956055

# %%
history = hist.history
loss_train = history['loss']
loss_val = history['val_loss']

plt.figure()
plt.plot(loss_train, label='train')
plt.plot(loss_val, label='val_loss', color='red')
plt.legend()

# %%
y_pred = model.predict(x_test)
diff = y_test - y_pred
diff_roll = diff[:, 0]
diff_pitch = diff[:, 1]
diff_yaw = diff[:, 2]

plt.figure(figsize=(16, 10))

plt.subplot(3, 1, 1)
plt.plot(diff_roll, color='red')
plt.title('roll')

plt.subplot(3, 1, 2)
plt.plot(diff_pitch, color='red')
plt.title('pitch')

plt.subplot(3, 1, 3)
plt.plot(diff_yaw, color='red')
plt.title('yaw')

plt.tight_layout()

# %%
# !wget http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2
# !bunzip2 "shape_predictor_68_face_landmarks.dat.bz2"
# Out:
# --2020-08-06 08:31:42--  http://dlib.net/files/shape_predictor_68_face_landmarks.dat.bz2
# Resolving dlib.net (dlib.net)... 107.180.26.78
# Connecting to dlib.net (dlib.net)|107.180.26.78|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 64040097 (61M)
# Saving to: ‘shape_predictor_68_face_landmarks.dat.bz2’
#
# shape_predictor_68_ 100%[===================>]  61.07M  14.3MB/s    in 4.8s
#
# 2020-08-06 08:31:47 (12.7 MB/s) - ‘shape_predictor_68_face_landmarks.dat.bz2’ saved [64040097/64040097]

# %%
import dlib
def detect_face_points(image):
    detector = dlib.get_frontal_face_detector()
    predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")
    face_rect = detector(image, 1)
    if len(face_rect) != 1: return []
    
    dlib_points = predictor(image, face_rect[0])
    face_points = []
    for i in range(68):
        x, y = dlib_points.part(i).x, dlib_points.part(i).y
        face_points.append(np.array([x, y]))
    return face_points
        
def compute_features(face_points):
    assert (len(face_points) == 68), "len(face_points) must be 68"
    
    face_points = np.array(face_points)
    features = []
    for i in range(68):
        for j in range(i+1, 68):
            features.append(np.linalg.norm(face_points[i]-face_points[j]))
            
    return np.array(features).reshape(1, -1)

# %%
im = cv2.imread('../input/picimage/lena.png', cv2.IMREAD_COLOR)
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
face_points = detect_face_points(im)

for x, y in face_points:
    cv2.circle(im, (x, y), 1, (0, 255, 0), -1)
    
features = compute_features(face_points)



y_pred = model.predict(features)

roll_pred, pitch_pred, yaw_pred = y_pred[0]
print(' Roll: {:.2f}°'.format(roll_pred))
print('Pitch: {:.2f}°'.format(pitch_pred))
print('  Yaw: {:.2f}°'.format(yaw_pred))
    
plt.figure(figsize=(10, 10))
plt.imshow(im)
# Out:
#  Roll: 445.00°
# Pitch: -334.50°
#   Yaw: 380.89°
